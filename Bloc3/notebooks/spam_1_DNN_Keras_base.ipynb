# %% [markdown]
# ---
# # DNN : `spam` (avec `Keras`, version de base)
# ---

# %% [markdown]
# ## Packages

# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras import layers, models
# Out:
# 2025-06-11 13:40:31.741660: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-11 13:40:31.746567: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-11 13:40:31.760137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749649231.780742   21138 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749649231.786969   21138 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749649231.804488   21138 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749649231.804507   21138 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749649231.804510   21138 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749649231.804512   21138 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-11 13:40:31.809651: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ---
# ## 1. Données
# ---

# %% [markdown]
# ### 1.1. Importation

# %%
# En local :
# directory = '/Users/vincentlefieux/Dropbox/Docs_ACADEMIQUE/Data/'

# Sur Google collab ou Onyxia (sur un répertoire temporaire) :
# directory = ''

# Sur Google collab (sur le drive) :
# from google.colab import drive
# drive.mount('/content/drive')
# directory = '/content/drive/MyDrive/Data/'

# %%
data = pd.read_csv('/home/onyxia/work/formation_cepe/Bloc3/data/spam.csv',
                   header    = 0,
                   # index_col = 0,
                   sep       = ',',
                   decimal   = '.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
#  13  word_freq_report            4601 non-null   float64
#  14  word_freq_addresses         4601 non-null   float64
#  15  word_freq_free              4601 non-null   float64
#  16  word_freq_business          4601 non-null   float64
#  17  word_freq_email             4601 non-null   float64
#  18  word_freq_you               4601 non-null   float64
#  19  word_freq_credit            4601 non-null   float64
#  20  word_freq_your              4601 non-null   float64
#  21  word_freq_font              4601 non-null   float64
#  22  word_freq_000               4601 non-null   float64
#  23  word_freq_money             4601 non-null   float64
#  24  word_freq_hp                4601 non-null   float64
#  25  word_freq_hpl               4601 non-null   float64
#  26  word_freq_george            4601 non-null   float64
#  27  word_freq_650               4601 non-null   float64
#  28  word_freq_lab               4601 non-null   float64
#  29  word_freq_labs              4601 non-null   float64
#  30  word_freq_telnet            4601 non-null   float64
#  31  word_freq_857               4601 non-null   float64
#  32  word_freq_data              4601 non-null   float64
#  33  word_freq_415               4601 non-null   float64
#  34  word_freq_85                4601 non-null   float64
#  35  word_freq_technology        4601 non-null   float64
#  36  word_freq_1999              4601 non-null   float64
#  37  word_freq_parts             4601 non-null   float64
#  38  word_freq_pm                4601 non-null   float64
#  39  word_freq_direct            4601 non-null   float64
#  40  word_freq_cs                4601 non-null   float64
#  41  word_freq_meeting           4601 non-null   float64
#  42  word_freq_original          4601 non-null   float64
#  43  word_freq_project           4601 non-null   float64
#  44  word_freq_re                4601 non-null   float64
#  45  word_freq_edu               4601 non-null   float64
#  46  word_freq_table             4601 non-null   float64
#  47  word_freq_conference        4601 non-null   float64
#  48  char_freq_semicolon         4601 non-null   float64
#  49  char_freq_leftbrac          4601 non-null   float64
#  50  char_freq_leftsquarebrac    4601 non-null   float64
#  51  char_freq_exclaim           4601 non-null   float64
#  52  char_freq_dollar            4601 non-null   float64
#  53  char_freq_pound             4601 non-null   float64
#  54  capital_run_length_average  4601 non-null   float64
#  55  capital_run_length_longest  4601 non-null   int64
#  56  capital_run_length_total    4601 non-null   int64
#  57  spam                        4601 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_semicolon  \
# 0             0.00            0.00  ...                 0.00
# 1             0.00            0.94  ...                 0.00
# 2             0.64            0.25  ...                 0.01
# 3             0.31            0.63  ...                 0.00
# 4             0.31            0.63  ...                 0.00
#
#    char_freq_leftbrac  char_freq_leftsquarebrac  char_freq_exclaim  \
# 0               0.000                       0.0              0.778
# 1               0.132                       0.0              0.372
# 2               0.143                       0.0              0.276
# 3               0.137                       0.0              0.137
# 4               0.135                       0.0              0.135
#
#    char_freq_dollar  char_freq_pound  capital_run_length_average  \
# 0             0.000            0.000                       3.756
# 1             0.180            0.048                       5.114
# 2             0.184            0.010                       9.821
# 3             0.000            0.000                       3.537
# 4             0.000            0.000                       3.537
#
#    capital_run_length_longest  capital_run_length_total  spam
# 0                          61                       278     1
# 1                         101                      1028     1
# 2                         485                      2259     1
# 3                          40                       191     1
# 4                          40                       191     1
#
# [5 rows x 58 columns]

# %% [markdown]
# ### 1.2. Gestion des données manquantes

# %%
missing_percentage = data.isna().mean() * 100

print('MISSING VALUES :')
if missing_percentage[missing_percentage != 0].empty:
    print('No')
else:
    print(missing_percentage[missing_percentage != 0].sort_values(ascending=False))
# Out:
# MISSING VALUES :
# No

# %% [markdown]
# ### 1.3. Gestion des variables

# %%
target = 'spam'

y = data[target]
X = data.drop(target, axis=1)

# %% [markdown]
# ### 1.4. Création des échantillons de validation et test

# %%
test_portion  = 1/5
valid_portion = 1/5

X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=test_portion)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=valid_portion)

print('Dimensions de X_train :', X_train.shape)
print('Dimensions de X_valid :', X_valid.shape)
print('Dimensions de X_test  :', X_test.shape)

print('Dimensions de y_train :', y_train.shape)
print('Dimensions de y_valid :', y_valid.shape)
print('Dimensions de y_test  :', y_test.shape)
# Out:
# Dimensions de X_train : (2944, 57)
# Dimensions de X_valid : (736, 57)
# Dimensions de X_test  : (921, 57)
# Dimensions de y_train : (2944,)
# Dimensions de y_valid : (736,)
# Dimensions de y_test  : (921,)

# %% [markdown]
# ### 1.5. Normalisation des covariables

# %% [markdown]
# On normalise (centrage-réduction) les covariables :

# %%
scaler = StandardScaler(with_mean=True, with_std=True)
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_valid_norm = scaler.transform(X_valid)
X_test_norm  = scaler.transform(X_test)

# %% [markdown]
# ---
# ## 2. DNN
# ---

# %% [markdown]
# ### 2.1. Architecture

# %%
dim_inputs  = (X_train_norm.shape[1],)
dim_outputs = 1

n_units_hl1 = 50
n_units_hl2 = 30

model = models.Sequential(name='DNN')

model.add(layers.Input(shape=dim_inputs, name='Inputs'))

model.add(layers.Dense(units=n_units_hl1, activation='relu', name='Hidden_layer_1'))

model.add(layers.Dense(units=n_units_hl2, activation='relu', name='Hidden_layer_2'))

model.add(layers.Dense(units=dim_outputs, activation='sigmoid', name='Output_layer'))

model.summary()
# Out:
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_layer_1 (Dense)          │ (None, 50)             │         2,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_layer_2 (Dense)          │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_layer (Dense)            │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,461 (17.43 KB)
#  Trainable params: 4,461 (17.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 30*(50+1) = 1530 neurones

# %% [markdown]
# ### 2.2. Optimiseur

# %%
model.compile(optimizer = 'adam',
              loss      = 'binary_crossentropy',
              metrics   = ['accuracy'])

# %% [markdown]
# ### 2.3. Entraînement

# %%
hist = model.fit(X_train_norm,
                 y_train,
                 batch_size      = 500,
                 epochs          = 200,
                 validation_data = (X_valid_norm, y_valid),
                 verbose         = 1)
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.5355 - loss: 0.7362 - val_accuracy: 0.6957 - val_loss: 0.6440
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7150 - loss: 0.6233 - val_accuracy: 0.7867 - val_loss: 0.5606
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8044 - loss: 0.5448 - val_accuracy: 0.8288 - val_loss: 0.4967
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8586 - loss: 0.4766 - val_accuracy: 0.8505 - val_loss: 0.4438
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8720 - loss: 0.4217 - val_accuracy: 0.8587 - val_loss: 0.3997
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8827 - loss: 0.3772 - val_accuracy: 0.8668 - val_loss: 0.3646
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8888 - loss: 0.3406 - val_accuracy: 0.8696 - val_loss: 0.3371
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9000 - loss: 0.3099 - val_accuracy: 0.8777 - val_loss: 0.3162
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9119 - loss: 0.2723 - val_accuracy: 0.8859 - val_loss: 0.3005
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9101 - loss: 0.2694 - val_accuracy: 0.8859 - val_loss: 0.2889
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9115 - loss: 0.2564 - val_accuracy: 0.8899 - val_loss: 0.2787
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9186 - loss: 0.2358 - val_accuracy: 0.8899 - val_loss: 0.2704
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9196 - loss: 0.2261 - val_accuracy: 0.8927 - val_loss: 0.2624
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9219 - loss: 0.2152 - val_accuracy: 0.8940 - val_loss: 0.2562
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9247 - loss: 0.2097 - val_accuracy: 0.8981 - val_loss: 0.2501
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9328 - loss: 0.2009 - val_accuracy: 0.8995 - val_loss: 0.2441
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9328 - loss: 0.1966 - val_accuracy: 0.8995 - val_loss: 0.2387
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9331 - loss: 0.1876 - val_accuracy: 0.8981 - val_loss: 0.2349
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9360 - loss: 0.1807 - val_accuracy: 0.9049 - val_loss: 0.2311
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9391 - loss: 0.1708 - val_accuracy: 0.9049 - val_loss: 0.2268
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9931 - loss: 0.0280 - val_accuracy: 0.9293 - val_loss: 0.2779
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9911 - loss: 0.0334 - val_accuracy: 0.9307 - val_loss: 0.2742
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9951 - loss: 0.0236 - val_accuracy: 0.9293 - val_loss: 0.2794
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9942 - loss: 0.0252 - val_accuracy: 0.9293 - val_loss: 0.2765
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9936 - loss: 0.0245 - val_accuracy: 0.9266 - val_loss: 0.2837
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9934 - loss: 0.0258 - val_accuracy: 0.9293 - val_loss: 0.2740
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9970 - loss: 0.0218 - val_accuracy: 0.9266 - val_loss: 0.2892
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9928 - loss: 0.0278 - val_accuracy: 0.9293 - val_loss: 0.2764
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9954 - loss: 0.0243 - val_accuracy: 0.9253 - val_loss: 0.2852
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9943 - loss: 0.0245 - val_accuracy: 0.9293 - val_loss: 0.2825
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9943 - loss: 0.0236 - val_accuracy: 0.9293 - val_loss: 0.2870
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9950 - loss: 0.0240 - val_accuracy: 0.9293 - val_loss: 0.2841
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9961 - loss: 0.0225 - val_accuracy: 0.9266 - val_loss: 0.2878
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9952 - loss: 0.0225 - val_accuracy: 0.9293 - val_loss: 0.2855
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9942 - loss: 0.0264 - val_accuracy: 0.9280 - val_loss: 0.2885
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9943 - loss: 0.0247 - val_accuracy: 0.9293 - val_loss: 0.2907
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9939 - loss: 0.0225 - val_accuracy: 0.9293 - val_loss: 0.2918
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9956 - loss: 0.0224 - val_accuracy: 0.9293 - val_loss: 0.2886
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9942 - loss: 0.0228 - val_accuracy: 0.9280 - val_loss: 0.2923
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9943 - loss: 0.0256 - val_accuracy: 0.9280 - val_loss: 0.2962
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9929 - loss: 0.0262 - val_accuracy: 0.9266 - val_loss: 0.2950
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9932 - loss: 0.0236 - val_accuracy: 0.9293 - val_loss: 0.2965
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9962 - loss: 0.0187 - val_accuracy: 0.9293 - val_loss: 0.2970
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9937 - loss: 0.0228 - val_accuracy: 0.9266 - val_loss: 0.2970
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9940 - loss: 0.0229 - val_accuracy: 0.9266 - val_loss: 0.2971
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9941 - loss: 0.0254 - val_accuracy: 0.9266 - val_loss: 0.3013
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9949 - loss: 0.0202 - val_accuracy: 0.9280 - val_loss: 0.3032
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9958 - loss: 0.0205 - val_accuracy: 0.9293 - val_loss: 0.2973

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['loss'], label='Train')
ax.plot(hist.history['val_loss'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Entropie')
ax.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['accuracy'], label='Train')
ax.plot(hist.history['val_accuracy'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Exactitude (accuracy)')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.4. Prévisions

# %%
y_test_pred = model.predict(X_test_norm)
y_test_pred[0:5]
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[0.9999681 ],
#        [1.        ],
#        [0.08929687],
#        [0.        ],
#        [0.01274816]], dtype=float32)

# %%
y_test_pred_classes = (y_test_pred > 0.5).astype(int)
y_test_pred_classes[0:5]
# Out:
# array([[1],
#        [1],
#        [0],
#        [0],
#        [0]])

# %%
score_test = model.evaluate(X_test_norm, y_test, verbose=0)
print(f'Entropie test   : {score_test[0]:4.4f}')
print(f'Exactitude test : {score_test[1]:4.4f}')
# Out:
# Entropie test   : 0.2189
# Exactitude test : 0.9446
