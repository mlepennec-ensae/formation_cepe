# %%
import os
import pandas as pd
import s3fs
import sklearn

# %%
os.environ['AWS_S3_ENDPOINT']
S3_ENDPOINT_URL = 'http://' + os.environ['AWS_S3_ENDPOINT']
fs = s3fs.S3FileSystem(client_kwargs = {'endpoint_url' :S3_ENDPOINT_URL })
fs.ls('mlepennec-ensae')
BUCKET = 'mlepennec-ensae'
FILE_KEY_S3 = '/engieX.csv'
FILE_PATH_S3 = BUCKET+FILE_KEY_S3
with fs.open(FILE_PATH_S3, mode = "rb") as file_in : 
    X_df = pd.read_csv(file_in, index_col=0,sep=';')

# %%
X_df
# Out:
#        MAC_CODE  Date_time  Pitch_angle  Pitch_angle_min  Pitch_angle_max  \
# ID
# 1           WT3        1.0    92.470001        92.470001        92.470001
# 2           WT3        2.0    92.470001        92.470001        92.470001
# 3           WT3        3.0    92.470001        92.470001        92.470001
# 4           WT3        4.0    92.470001        92.470001        92.470001
# 5           WT3        5.0    92.470001        92.470001        92.470001
# ...         ...        ...          ...              ...              ...
# 617382      WT1   157676.0    -1.010000        -1.010000        -0.840000
# 617383      WT1   157677.0    -1.010000        -1.010000        -1.010000
# 617384      WT1   157678.0    -0.810000        -1.010000         1.490000
# 617385      WT1   157679.0    -1.000000        -1.010000        -0.620000
# 617386      WT1   157680.0    -0.910000        -1.010000         1.080000
#
#         Pitch_angle_std  Hub_temperature  Hub_temperature_min  \
# ID
# ...

# %%
X_WT1_df = X_df[X_df.MAC_CODE == 'WT1']
X_WT1_df
# Out:
#        MAC_CODE  Date_time  Pitch_angle  Pitch_angle_min  Pitch_angle_max  \
# ID
# 462680      WT1        1.0    92.410004        92.410004        92.410004
# 462681      WT1        2.0    92.410004        92.410004        92.410004
# 462682      WT1        3.0    92.410004        92.410004        92.410004
# 462683      WT1        4.0    92.410004        92.410004        92.410004
# 462684      WT1        5.0    92.410004        92.410004        92.410004
# ...         ...        ...          ...              ...              ...
# 617382      WT1   157676.0    -1.010000        -1.010000        -0.840000
# 617383      WT1   157677.0    -1.010000        -1.010000        -1.010000
# 617384      WT1   157678.0    -0.810000        -1.010000         1.490000
# 617385      WT1   157679.0    -1.000000        -1.010000        -0.620000
# 617386      WT1   157680.0    -0.910000        -1.010000         1.080000
#
#         Pitch_angle_std  Hub_temperature  Hub_temperature_min  \
# ID
# ...
