# %% [markdown]
# ---
# # DNN : `spam` (avec `Keras`, version de base)
# ---

# %% [markdown]
# ## Packages

# %%
#pip install keras
#pip install tensorflow

# %%
#L'échantillon de validation sert à calibrer les hyperparamètres et l'échantillon de test sert à vérifier la générabilité du modèle
#Il est possible avant la mise en production de réentrainer le meilleur modèle sur toutes les données mais pas pour les réseaux de neurones
#L'architecture d'un réseau de neurones fait référence au nombre de couches et nombre de neurones par couche. Pour chaque architecture il faut optimiser aussi le nombre d'époques

# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras import layers, models
# Out:
# 2025-10-01 12:55:21.441311: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-01 12:55:21.531482: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-01 12:55:24.623693: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ---
# ## 1. Données
# ---

# %% [markdown]
# ### 1.1. Importation

# %%
# En local :
directory = '/Users/vincentlefieux/Dropbox/Docs_ACADEMIQUE/Data/'

# Sur Google collab ou Onyxia (sur un répertoire temporaire) :
# directory = ''

# Sur Google collab (sur le drive) :
# from google.colab import drive
# drive.mount('/content/drive')
# directory = '/content/drive/MyDrive/Data/'

# %%
data = pd.read_csv('spam.csv',
                   header    = 0,
                   # index_col = 0,
                   sep       = ',',
                   decimal   = '.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
#  13  word_freq_report            4601 non-null   float64
#  14  word_freq_addresses         4601 non-null   float64
#  15  word_freq_free              4601 non-null   float64
#  16  word_freq_business          4601 non-null   float64
#  17  word_freq_email             4601 non-null   float64
#  18  word_freq_you               4601 non-null   float64
#  19  word_freq_credit            4601 non-null   float64
#  20  word_freq_your              4601 non-null   float64
#  21  word_freq_font              4601 non-null   float64
#  22  word_freq_000               4601 non-null   float64
#  23  word_freq_money             4601 non-null   float64
#  24  word_freq_hp                4601 non-null   float64
#  25  word_freq_hpl               4601 non-null   float64
#  26  word_freq_george            4601 non-null   float64
#  27  word_freq_650               4601 non-null   float64
#  28  word_freq_lab               4601 non-null   float64
#  29  word_freq_labs              4601 non-null   float64
#  30  word_freq_telnet            4601 non-null   float64
#  31  word_freq_857               4601 non-null   float64
#  32  word_freq_data              4601 non-null   float64
#  33  word_freq_415               4601 non-null   float64
#  34  word_freq_85                4601 non-null   float64
#  35  word_freq_technology        4601 non-null   float64
#  36  word_freq_1999              4601 non-null   float64
#  37  word_freq_parts             4601 non-null   float64
#  38  word_freq_pm                4601 non-null   float64
#  39  word_freq_direct            4601 non-null   float64
#  40  word_freq_cs                4601 non-null   float64
#  41  word_freq_meeting           4601 non-null   float64
#  42  word_freq_original          4601 non-null   float64
#  43  word_freq_project           4601 non-null   float64
#  44  word_freq_re                4601 non-null   float64
#  45  word_freq_edu               4601 non-null   float64
#  46  word_freq_table             4601 non-null   float64
#  47  word_freq_conference        4601 non-null   float64
#  48  char_freq_semicolon         4601 non-null   float64
#  49  char_freq_leftbrac          4601 non-null   float64
#  50  char_freq_leftsquarebrac    4601 non-null   float64
#  51  char_freq_exclaim           4601 non-null   float64
#  52  char_freq_dollar            4601 non-null   float64
#  53  char_freq_pound             4601 non-null   float64
#  54  capital_run_length_average  4601 non-null   float64
#  55  capital_run_length_longest  4601 non-null   int64
#  56  capital_run_length_total    4601 non-null   int64
#  57  spam                        4601 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_semicolon  \
# 0             0.00            0.00  ...                 0.00
# 1             0.00            0.94  ...                 0.00
# 2             0.64            0.25  ...                 0.01
# 3             0.31            0.63  ...                 0.00
# 4             0.31            0.63  ...                 0.00
#
#    char_freq_leftbrac  char_freq_leftsquarebrac  char_freq_exclaim  \
# 0               0.000                       0.0              0.778
# 1               0.132                       0.0              0.372
# 2               0.143                       0.0              0.276
# 3               0.137                       0.0              0.137
# 4               0.135                       0.0              0.135
#
#    char_freq_dollar  char_freq_pound  capital_run_length_average  \
# 0             0.000            0.000                       3.756
# 1             0.180            0.048                       5.114
# 2             0.184            0.010                       9.821
# 3             0.000            0.000                       3.537
# 4             0.000            0.000                       3.537
#
#    capital_run_length_longest  capital_run_length_total  spam
# 0                          61                       278     1
# 1                         101                      1028     1
# 2                         485                      2259     1
# 3                          40                       191     1
# 4                          40                       191     1
#
# [5 rows x 58 columns]

# %% [markdown]
# ### 1.2. Gestion des données manquantes

# %%
missing_percentage = data.isna().mean() * 100

print('MISSING VALUES :')
if missing_percentage[missing_percentage != 0].empty:
    print('No')
else:
    print(missing_percentage[missing_percentage != 0].sort_values(ascending=False))
# Out:
# MISSING VALUES :
# No

# %% [markdown]
# ### 1.3. Gestion des variables

# %%
target = 'spam'

y = data[target]
X = data.drop(target, axis=1)

# %% [markdown]
# ### 1.4. Création des échantillons de validation et test

# %%
test_portion  = 1/5
valid_portion = 1/5

X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=test_portion)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=valid_portion)

print('Dimensions de X_train :', X_train.shape)
print('Dimensions de X_valid :', X_valid.shape)
print('Dimensions de X_test  :', X_test.shape)

print('Dimensions de y_train :', y_train.shape)
print('Dimensions de y_valid :', y_valid.shape)
print('Dimensions de y_test  :', y_test.shape)
# Out:
# Dimensions de X_train : (2944, 57)
# Dimensions de X_valid : (736, 57)
# Dimensions de X_test  : (921, 57)
# Dimensions de y_train : (2944,)
# Dimensions de y_valid : (736,)
# Dimensions de y_test  : (921,)

# %% [markdown]
# ### 1.5. Normalisation des covariables

# %% [markdown]
# On normalise (centrage-réduction) les covariables :

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_valid_norm = scaler.transform(X_valid)
X_test_norm  = scaler.transform(X_test)

# %% [markdown]
# ---
# ## 2. DNN
# ---

# %% [markdown]
# ### 2.1. Architecture

# %%
dim_inputs  = (X_train_norm.shape[1],)
dim_outputs = 1

n_units_hl1 = 50
n_units_hl2 = 30

model = models.Sequential(name='DNN')

model.add(layers.Input(shape=dim_inputs, name='Inputs'))

model.add(layers.Dense(units=n_units_hl1, activation='relu', name='Hidden_layer_1'))

model.add(layers.Dense(units=n_units_hl2, activation='relu', name='Hidden_layer_2'))

model.add(layers.Dense(units=dim_outputs, activation='sigmoid', name='Output_layer'))

model.summary()
# Out:
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_layer_1 (Dense)          │ (None, 50)             │         2,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_layer_2 (Dense)          │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_layer (Dense)            │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,461 (17.43 KB)
#  Trainable params: 4,461 (17.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2.2. Optimiseur

# %%
model.compile(optimizer = 'adam',
              loss      = 'binary_crossentropy',
              metrics   = ['accuracy'])

# %% [markdown]
# ### 2.3. Entraînement

# %%
hist = model.fit(X_train_norm,
                 y_train,
                 batch_size      = 500,
                 epochs          = 200,
                 validation_data = (X_valid_norm, y_valid),
                 verbose         = 1)
                 #garde en mémoire le modèle si on relance le code
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.5893 - loss: 0.7235 - val_accuracy: 0.6739 - val_loss: 0.6545
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7272 - loss: 0.6112 - val_accuracy: 0.7527 - val_loss: 0.5767
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.7952 - loss: 0.5350 - val_accuracy: 0.8043 - val_loss: 0.5205
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8332 - loss: 0.4770 - val_accuracy: 0.8356 - val_loss: 0.4711
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8573 - loss: 0.4256 - val_accuracy: 0.8573 - val_loss: 0.4279
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8784 - loss: 0.3817 - val_accuracy: 0.8723 - val_loss: 0.3922
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8879 - loss: 0.3444 - val_accuracy: 0.8750 - val_loss: 0.3639
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8950 - loss: 0.3147 - val_accuracy: 0.8791 - val_loss: 0.3418
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8995 - loss: 0.2909 - val_accuracy: 0.8872 - val_loss: 0.3239
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9090 - loss: 0.2716 - val_accuracy: 0.8927 - val_loss: 0.3094
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9130 - loss: 0.2555 - val_accuracy: 0.8954 - val_loss: 0.2977
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9158 - loss: 0.2431 - val_accuracy: 0.8981 - val_loss: 0.2882
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9171 - loss: 0.2327 - val_accuracy: 0.8995 - val_loss: 0.2795
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9198 - loss: 0.2236 - val_accuracy: 0.9090 - val_loss: 0.2725
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9229 - loss: 0.2162 - val_accuracy: 0.9090 - val_loss: 0.2663
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9236 - loss: 0.2092 - val_accuracy: 0.9117 - val_loss: 0.2602
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9249 - loss: 0.2029 - val_accuracy: 0.9117 - val_loss: 0.2548
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9293 - loss: 0.1975 - val_accuracy: 0.9144 - val_loss: 0.2499
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9321 - loss: 0.1925 - val_accuracy: 0.9144 - val_loss: 0.2454
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9327 - loss: 0.1880 - val_accuracy: 0.9144 - val_loss: 0.2412
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9341 - loss: 0.1838 - val_accuracy: 0.9171 - val_loss: 0.2365
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9348 - loss: 0.1802 - val_accuracy: 0.9144 - val_loss: 0.2331
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9351 - loss: 0.1764 - val_accuracy: 0.9144 - val_loss: 0.2299
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9358 - loss: 0.1731 - val_accuracy: 0.9158 - val_loss: 0.2258
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9372 - loss: 0.1697 - val_accuracy: 0.9171 - val_loss: 0.2227
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9385 - loss: 0.1665 - val_accuracy: 0.9171 - val_loss: 0.2194
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9399 - loss: 0.1636 - val_accuracy: 0.9171 - val_loss: 0.2162
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9426 - loss: 0.1609 - val_accuracy: 0.9185 - val_loss: 0.2130
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9433 - loss: 0.1583 - val_accuracy: 0.9198 - val_loss: 0.2116
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9433 - loss: 0.1557 - val_accuracy: 0.9212 - val_loss: 0.2098
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9443 - loss: 0.1533 - val_accuracy: 0.9226 - val_loss: 0.2068
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9450 - loss: 0.1509 - val_accuracy: 0.9253 - val_loss: 0.2045
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9450 - loss: 0.1488 - val_accuracy: 0.9253 - val_loss: 0.2022
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9450 - loss: 0.1467 - val_accuracy: 0.9253 - val_loss: 0.2001
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9467 - loss: 0.1449 - val_accuracy: 0.9266 - val_loss: 0.1987
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9474 - loss: 0.1426 - val_accuracy: 0.9280 - val_loss: 0.1974
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9484 - loss: 0.1406 - val_accuracy: 0.9266 - val_loss: 0.1963
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9487 - loss: 0.1388 - val_accuracy: 0.9280 - val_loss: 0.1954
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9504 - loss: 0.1369 - val_accuracy: 0.9280 - val_loss: 0.1947
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9507 - loss: 0.1351 - val_accuracy: 0.9293 - val_loss: 0.1939
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9514 - loss: 0.1333 - val_accuracy: 0.9307 - val_loss: 0.1920
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9524 - loss: 0.1315 - val_accuracy: 0.9307 - val_loss: 0.1915
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9528 - loss: 0.1298 - val_accuracy: 0.9293 - val_loss: 0.1907
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9545 - loss: 0.1282 - val_accuracy: 0.9321 - val_loss: 0.1903
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9541 - loss: 0.1265 - val_accuracy: 0.9334 - val_loss: 0.1895
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9541 - loss: 0.1248 - val_accuracy: 0.9321 - val_loss: 0.1890
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9545 - loss: 0.1232 - val_accuracy: 0.9321 - val_loss: 0.1889
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9562 - loss: 0.1218 - val_accuracy: 0.9361 - val_loss: 0.1884
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9558 - loss: 0.1202 - val_accuracy: 0.9361 - val_loss: 0.1880
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9569 - loss: 0.1187 - val_accuracy: 0.9361 - val_loss: 0.1871
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9572 - loss: 0.1172 - val_accuracy: 0.9375 - val_loss: 0.1863
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9589 - loss: 0.1157 - val_accuracy: 0.9375 - val_loss: 0.1857
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9586 - loss: 0.1141 - val_accuracy: 0.9389 - val_loss: 0.1856
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9575 - loss: 0.1127 - val_accuracy: 0.9389 - val_loss: 0.1855
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9586 - loss: 0.1114 - val_accuracy: 0.9375 - val_loss: 0.1851
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9596 - loss: 0.1099 - val_accuracy: 0.9389 - val_loss: 0.1856
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9616 - loss: 0.1086 - val_accuracy: 0.9389 - val_loss: 0.1854
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9626 - loss: 0.1072 - val_accuracy: 0.9389 - val_loss: 0.1851
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9626 - loss: 0.1060 - val_accuracy: 0.9389 - val_loss: 0.1844
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9630 - loss: 0.1046 - val_accuracy: 0.9389 - val_loss: 0.1836
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9633 - loss: 0.1031 - val_accuracy: 0.9389 - val_loss: 0.1832
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9637 - loss: 0.1019 - val_accuracy: 0.9389 - val_loss: 0.1827
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9633 - loss: 0.1007 - val_accuracy: 0.9402 - val_loss: 0.1830
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9643 - loss: 0.0995 - val_accuracy: 0.9402 - val_loss: 0.1827
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9643 - loss: 0.0982 - val_accuracy: 0.9389 - val_loss: 0.1832
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9650 - loss: 0.0971 - val_accuracy: 0.9402 - val_loss: 0.1831
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9667 - loss: 0.0959 - val_accuracy: 0.9402 - val_loss: 0.1836
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9667 - loss: 0.0946 - val_accuracy: 0.9443 - val_loss: 0.1823
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9671 - loss: 0.0934 - val_accuracy: 0.9416 - val_loss: 0.1828
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9671 - loss: 0.0923 - val_accuracy: 0.9416 - val_loss: 0.1824
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9674 - loss: 0.0911 - val_accuracy: 0.9429 - val_loss: 0.1822
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9684 - loss: 0.0901 - val_accuracy: 0.9429 - val_loss: 0.1823
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9681 - loss: 0.0893 - val_accuracy: 0.9429 - val_loss: 0.1835
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9691 - loss: 0.0878 - val_accuracy: 0.9416 - val_loss: 0.1826
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9691 - loss: 0.0867 - val_accuracy: 0.9416 - val_loss: 0.1834
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9698 - loss: 0.0857 - val_accuracy: 0.9416 - val_loss: 0.1839
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9711 - loss: 0.0846 - val_accuracy: 0.9416 - val_loss: 0.1841
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9708 - loss: 0.0835 - val_accuracy: 0.9402 - val_loss: 0.1855
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9704 - loss: 0.0825 - val_accuracy: 0.9402 - val_loss: 0.1844
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9732 - loss: 0.0815 - val_accuracy: 0.9402 - val_loss: 0.1851
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9735 - loss: 0.0804 - val_accuracy: 0.9429 - val_loss: 0.1843
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9742 - loss: 0.0796 - val_accuracy: 0.9429 - val_loss: 0.1844
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9745 - loss: 0.0784 - val_accuracy: 0.9429 - val_loss: 0.1858
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9745 - loss: 0.0776 - val_accuracy: 0.9429 - val_loss: 0.1861
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9752 - loss: 0.0767 - val_accuracy: 0.9429 - val_loss: 0.1865
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9745 - loss: 0.0757 - val_accuracy: 0.9429 - val_loss: 0.1885
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9766 - loss: 0.0748 - val_accuracy: 0.9457 - val_loss: 0.1886
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9772 - loss: 0.0739 - val_accuracy: 0.9457 - val_loss: 0.1873
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9789 - loss: 0.0732 - val_accuracy: 0.9457 - val_loss: 0.1872
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9796 - loss: 0.0720 - val_accuracy: 0.9457 - val_loss: 0.1884
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9796 - loss: 0.0712 - val_accuracy: 0.9470 - val_loss: 0.1901
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9800 - loss: 0.0704 - val_accuracy: 0.9470 - val_loss: 0.1906
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9800 - loss: 0.0696 - val_accuracy: 0.9470 - val_loss: 0.1905
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9813 - loss: 0.0688 - val_accuracy: 0.9470 - val_loss: 0.1898
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9827 - loss: 0.0680 - val_accuracy: 0.9484 - val_loss: 0.1895
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9830 - loss: 0.0671 - val_accuracy: 0.9470 - val_loss: 0.1926
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9834 - loss: 0.0666 - val_accuracy: 0.9470 - val_loss: 0.1929
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9823 - loss: 0.0658 - val_accuracy: 0.9484 - val_loss: 0.1923
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9844 - loss: 0.0654 - val_accuracy: 0.9457 - val_loss: 0.1941
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9837 - loss: 0.0641 - val_accuracy: 0.9484 - val_loss: 0.1940
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9844 - loss: 0.0634 - val_accuracy: 0.9470 - val_loss: 0.1945
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9837 - loss: 0.0625 - val_accuracy: 0.9470 - val_loss: 0.1967
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9847 - loss: 0.0619 - val_accuracy: 0.9470 - val_loss: 0.1982
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9854 - loss: 0.0613 - val_accuracy: 0.9484 - val_loss: 0.1973
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9857 - loss: 0.0602 - val_accuracy: 0.9470 - val_loss: 0.1975
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9868 - loss: 0.0598 - val_accuracy: 0.9470 - val_loss: 0.1980
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9857 - loss: 0.0589 - val_accuracy: 0.9484 - val_loss: 0.1998
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9854 - loss: 0.0584 - val_accuracy: 0.9470 - val_loss: 0.2031
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9861 - loss: 0.0576 - val_accuracy: 0.9470 - val_loss: 0.2022
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9864 - loss: 0.0571 - val_accuracy: 0.9470 - val_loss: 0.2018
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9868 - loss: 0.0567 - val_accuracy: 0.9497 - val_loss: 0.2034
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9864 - loss: 0.0558 - val_accuracy: 0.9497 - val_loss: 0.2045
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9861 - loss: 0.0552 - val_accuracy: 0.9484 - val_loss: 0.2071
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9871 - loss: 0.0545 - val_accuracy: 0.9497 - val_loss: 0.2070
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9857 - loss: 0.0538 - val_accuracy: 0.9470 - val_loss: 0.2083
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9871 - loss: 0.0531 - val_accuracy: 0.9470 - val_loss: 0.2080
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9874 - loss: 0.0530 - val_accuracy: 0.9497 - val_loss: 0.2092
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9888 - loss: 0.0526 - val_accuracy: 0.9484 - val_loss: 0.2103
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9888 - loss: 0.0511 - val_accuracy: 0.9511 - val_loss: 0.2111
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9874 - loss: 0.0512 - val_accuracy: 0.9497 - val_loss: 0.2123
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9878 - loss: 0.0509 - val_accuracy: 0.9470 - val_loss: 0.2143
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9891 - loss: 0.0495 - val_accuracy: 0.9497 - val_loss: 0.2138
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9881 - loss: 0.0492 - val_accuracy: 0.9484 - val_loss: 0.2156
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9888 - loss: 0.0495 - val_accuracy: 0.9484 - val_loss: 0.2183
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9888 - loss: 0.0484 - val_accuracy: 0.9511 - val_loss: 0.2206
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9885 - loss: 0.0477 - val_accuracy: 0.9470 - val_loss: 0.2199
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9901 - loss: 0.0470 - val_accuracy: 0.9484 - val_loss: 0.2207
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9891 - loss: 0.0466 - val_accuracy: 0.9511 - val_loss: 0.2223
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9895 - loss: 0.0457 - val_accuracy: 0.9470 - val_loss: 0.2219
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9891 - loss: 0.0454 - val_accuracy: 0.9497 - val_loss: 0.2234
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9891 - loss: 0.0449 - val_accuracy: 0.9484 - val_loss: 0.2273
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9895 - loss: 0.0441 - val_accuracy: 0.9484 - val_loss: 0.2285
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9898 - loss: 0.0439 - val_accuracy: 0.9484 - val_loss: 0.2284
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9898 - loss: 0.0431 - val_accuracy: 0.9484 - val_loss: 0.2280
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9901 - loss: 0.0426 - val_accuracy: 0.9484 - val_loss: 0.2305
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9898 - loss: 0.0422 - val_accuracy: 0.9484 - val_loss: 0.2331
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9898 - loss: 0.0417 - val_accuracy: 0.9497 - val_loss: 0.2340
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9898 - loss: 0.0411 - val_accuracy: 0.9484 - val_loss: 0.2344
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9901 - loss: 0.0407 - val_accuracy: 0.9497 - val_loss: 0.2354
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9905 - loss: 0.0406 - val_accuracy: 0.9497 - val_loss: 0.2359
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9895 - loss: 0.0403 - val_accuracy: 0.9511 - val_loss: 0.2376
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9898 - loss: 0.0393 - val_accuracy: 0.9497 - val_loss: 0.2400
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9895 - loss: 0.0388 - val_accuracy: 0.9497 - val_loss: 0.2429
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9905 - loss: 0.0385 - val_accuracy: 0.9511 - val_loss: 0.2432
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9898 - loss: 0.0378 - val_accuracy: 0.9497 - val_loss: 0.2435
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9901 - loss: 0.0374 - val_accuracy: 0.9511 - val_loss: 0.2464
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9908 - loss: 0.0375 - val_accuracy: 0.9511 - val_loss: 0.2451
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9912 - loss: 0.0367 - val_accuracy: 0.9511 - val_loss: 0.2482
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9908 - loss: 0.0362 - val_accuracy: 0.9484 - val_loss: 0.2504
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9915 - loss: 0.0360 - val_accuracy: 0.9511 - val_loss: 0.2499
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9912 - loss: 0.0354 - val_accuracy: 0.9511 - val_loss: 0.2534
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9905 - loss: 0.0350 - val_accuracy: 0.9511 - val_loss: 0.2561
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9912 - loss: 0.0345 - val_accuracy: 0.9511 - val_loss: 0.2557
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9905 - loss: 0.0343 - val_accuracy: 0.9497 - val_loss: 0.2557
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9918 - loss: 0.0342 - val_accuracy: 0.9497 - val_loss: 0.2573
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9915 - loss: 0.0336 - val_accuracy: 0.9484 - val_loss: 0.2599
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9915 - loss: 0.0332 - val_accuracy: 0.9497 - val_loss: 0.2614
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9908 - loss: 0.0332 - val_accuracy: 0.9484 - val_loss: 0.2628
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9912 - loss: 0.0327 - val_accuracy: 0.9511 - val_loss: 0.2637
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9908 - loss: 0.0325 - val_accuracy: 0.9484 - val_loss: 0.2632
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9908 - loss: 0.0318 - val_accuracy: 0.9497 - val_loss: 0.2651
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9915 - loss: 0.0319 - val_accuracy: 0.9497 - val_loss: 0.2677
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9912 - loss: 0.0316 - val_accuracy: 0.9457 - val_loss: 0.2691
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9918 - loss: 0.0307 - val_accuracy: 0.9484 - val_loss: 0.2707
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9925 - loss: 0.0309 - val_accuracy: 0.9470 - val_loss: 0.2705
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9915 - loss: 0.0309 - val_accuracy: 0.9470 - val_loss: 0.2745
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9932 - loss: 0.0308 - val_accuracy: 0.9470 - val_loss: 0.2768
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9918 - loss: 0.0304 - val_accuracy: 0.9457 - val_loss: 0.2756
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9922 - loss: 0.0294 - val_accuracy: 0.9484 - val_loss: 0.2778
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9935 - loss: 0.0292 - val_accuracy: 0.9443 - val_loss: 0.2805
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9925 - loss: 0.0289 - val_accuracy: 0.9457 - val_loss: 0.2818
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9929 - loss: 0.0283 - val_accuracy: 0.9470 - val_loss: 0.2815
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9925 - loss: 0.0282 - val_accuracy: 0.9457 - val_loss: 0.2814
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9925 - loss: 0.0282 - val_accuracy: 0.9457 - val_loss: 0.2858
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9932 - loss: 0.0282 - val_accuracy: 0.9457 - val_loss: 0.2846
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9925 - loss: 0.0279 - val_accuracy: 0.9457 - val_loss: 0.2889
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9935 - loss: 0.0269 - val_accuracy: 0.9443 - val_loss: 0.2882
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9939 - loss: 0.0269 - val_accuracy: 0.9457 - val_loss: 0.2880
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9932 - loss: 0.0266 - val_accuracy: 0.9457 - val_loss: 0.2914
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9932 - loss: 0.0263 - val_accuracy: 0.9457 - val_loss: 0.2930
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9935 - loss: 0.0258 - val_accuracy: 0.9457 - val_loss: 0.2939
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9939 - loss: 0.0258 - val_accuracy: 0.9457 - val_loss: 0.2951
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9942 - loss: 0.0258 - val_accuracy: 0.9457 - val_loss: 0.2985
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9935 - loss: 0.0255 - val_accuracy: 0.9457 - val_loss: 0.3000
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9946 - loss: 0.0252 - val_accuracy: 0.9457 - val_loss: 0.2993
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9939 - loss: 0.0246 - val_accuracy: 0.9443 - val_loss: 0.3005
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9939 - loss: 0.0245 - val_accuracy: 0.9443 - val_loss: 0.3022
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9942 - loss: 0.0244 - val_accuracy: 0.9457 - val_loss: 0.3053
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9939 - loss: 0.0242 - val_accuracy: 0.9429 - val_loss: 0.3056
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9949 - loss: 0.0240 - val_accuracy: 0.9429 - val_loss: 0.3072
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9939 - loss: 0.0248 - val_accuracy: 0.9429 - val_loss: 0.3105
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9956 - loss: 0.0236 - val_accuracy: 0.9457 - val_loss: 0.3098
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9946 - loss: 0.0233 - val_accuracy: 0.9429 - val_loss: 0.3105
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9939 - loss: 0.0235 - val_accuracy: 0.9443 - val_loss: 0.3142
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9946 - loss: 0.0232 - val_accuracy: 0.9429 - val_loss: 0.3164
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9939 - loss: 0.0229 - val_accuracy: 0.9429 - val_loss: 0.3151
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9956 - loss: 0.0225 - val_accuracy: 0.9443 - val_loss: 0.3150
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9942 - loss: 0.0221 - val_accuracy: 0.9429 - val_loss: 0.3192
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9946 - loss: 0.0221 - val_accuracy: 0.9443 - val_loss: 0.3216
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9949 - loss: 0.0217 - val_accuracy: 0.9429 - val_loss: 0.3217

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['loss'], label='Train')
ax.plot(hist.history['val_loss'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Entropie')
ax.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['accuracy'], label='Train')
ax.plot(hist.history['val_accuracy'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Exactitude (accuracy)')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.4. Prévisions

# %%
y_test_pred = model.predict(X_test_norm)
y_test_pred[0:5]
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[1.0000000e+00],
#        [2.8757905e-08],
#        [9.9824196e-01],
#        [1.2794634e-05],
#        [7.4216064e-06]], dtype=float32)

# %%
y_test_pred_classes = (y_test_pred > 0.5).astype(int)
y_test_pred_classes[0:5]
# Out:
# array([[1],
#        [0],
#        [1],
#        [0],
#        [0]])

# %%
score_test = model.evaluate(X_test_norm, y_test, verbose=0)
print(f'Entropie test   : {score_test[0]:4.4f}')
print(f'Exactitude test : {score_test[1]:4.4f}')
# Out:
# Entropie test   : 0.3287
# Exactitude test : 0.9283
